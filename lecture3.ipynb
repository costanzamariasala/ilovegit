# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

import scipy.stats
from scipy.stats import norm
from scipy.stats import uniform
from astroML import stats as astroMLstats
from tqdm.notebook import tqdm
plt.rcParams['figure.figsize'] = [6, 6]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 9
#       7 from scipy.stats import norm
#       8 from scipy.stats import uniform
# ----> 9 from astroML import stats as astroMLstats
#      10 from tqdm.notebook import tqdm
#      11 plt.rcParams['figure.figsize'] = [6, 6]
#
# ModuleNotFoundError: No module named 'astroML'

# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

import scipy.stats
from scipy.stats import norm
from scipy.stats import uniform
from astroML import stats as astroMLstats
from tqdm.notebook import tqdm
plt.rcParams['figure.figsize'] = [6, 6]
N = 2 # Number of draws
mu = 0.5 # Location
sigma_h = 1.0 / np.sqrt(12) # scale of h(x)

xgrid = np.linspace(-1,2,100)  
distG = scipy.stats.norm(loc=mu, scale=sigma_h)
plt.plot(xgrid, distG.pdf(xgrid))

x = np.random.normal(mu, sigma_h,2) # Two random draws
plt.plot(x, 0*x, '|', markersize=50)
plt.xlabel('x')
plt.ylabel('pdf');
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 9
#       7 from scipy.stats import norm
#       8 from scipy.stats import uniform
# ----> 9 from astroML import stats as astroMLstats
#      10 from tqdm.notebook import tqdm
#      11 plt.rcParams['figure.figsize'] = [6, 6]
#
# ModuleNotFoundError: No module named 'astroML'
