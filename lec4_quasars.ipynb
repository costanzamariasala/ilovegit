# %%
import numpy as np
from astroML.datasets import fetch_dr7_quasar

#fetch the quasar data
data = fetch_dr7_quasar()

# select the first 10000 points
data = data[:10000]

z = data['redshift']
# Out:
# downloading DR7 quasar dataset from http://das.sdss.org/va/qsocat/dr7qso.dat.gz to /home/costanza_maria_sala/astroML_data
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 5
#       2 from astroML.datasets import fetch_dr7_quasar
#       4 #fetch the quasar data
# ----> 5 data = fetch_dr7_quasar()
#       7 # select the first 10000 points
#       8 data = data[:10000]
#
# File ~/.local/lib/python3.12/site-packages/astroML/datasets/dr7_quasar.py:103, in fetch_dr7_quasar(data_home, download_if_missing)
#      97     raise IOError('data not present on disk. '
#      98                   'set download_if_missing=True to download')
#     100 print("downloading DR7 quasar dataset from %s to %s"
#     101       % (DATA_URL, data_home))
# --> 103 zipped_buf = download_with_progress_bar(DATA_URL, return_buffer=True)
#     104 gzf = GzipFile(fileobj=zipped_buf, mode='rb')
#     105 extracted_buf = BytesIO(gzf.read())
#
# File ~/.local/lib/python3.12/site-packages/astroML/datasets/tools/download.py:45, in download_with_progress_bar(data_url, return_buffer)
#      42 num_units = 40
#      44 fhandle = urlopen(data_url)
# ---> 45 content_length = url_content_length(fhandle)
#      47 chunk_size = content_length // num_units
#      49 print("Downloading %s" % data_url)
#
# File ~/.local/lib/python3.12/site-packages/astroML/datasets/tools/download.py:23, in url_content_length(fhandle)
#      22 def url_content_length(fhandle):
# ---> 23     length = dict(fhandle.info())['Content-Length']
#      24     return int(length.strip())
#
# KeyError: 'Content-Length'
